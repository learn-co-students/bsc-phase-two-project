# %%
import pandas as pd

# %%
df = pd.read_csv('../../../data/kc_house_data.csv')

# %% [markdown]
# # Column Names and descriptions for Kings County Data Set
# * **id** - unique identified for a house
# * **dateDate** - house was sold
# * **pricePrice** -  is prediction target
# * **bedroomsNumber** -  of Bedrooms/House
# * **bathroomsNumber** -  of bathrooms/bedrooms
# * **sqft_livingsquare** -  footage of the home
# * **sqft_lotsquare** -  footage of the lot
# * **floorsTotal** -  floors (levels) in house
# * **waterfront** - House which has a view to a waterfront
# * **view** - Has been viewed
# * **condition** - How good the condition is ( Overall )
# * **grade** - overall grade given to the housing unit, based on King County grading system
# * **sqft_above** - square footage of house apart from basement
# * **sqft_basement** - square footage of the basement
# * **yr_built** - Built Year
# * **yr_renovated** - Year when house was renovated
# * **zipcode** - zip
# * **lat** - Latitude coordinate
# * **long** - Longitude coordinate
# * **sqft_living15** - The square footage of interior housing living space for the nearest 15 neighbors
# * **sqft_lot15** - The square footage of the land lots of the nearest 15 neighbors

# %%
new_df = df[['id','price', 'sqft_living', 'grade', 'sqft_above', 'sqft_living15', 'bathrooms', 'view', 'bedrooms', 'lat', 'waterfront', 'floors']]
new_df
# Out:
#                id     price  sqft_living  grade  sqft_above  sqft_living15  \
# 0      7129300520  221900.0         1180      7        1180           1340
# 1      6414100192  538000.0         2570      7        2170           1690
# 2      5631500400  180000.0          770      6         770           2720
# 3      2487200875  604000.0         1960      7        1050           1360
# 4      1954400510  510000.0         1680      8        1680           1800
# ...           ...       ...          ...    ...         ...            ...
# 21592   263000018  360000.0         1530      8        1530           1530
# 21593  6600060120  400000.0         2310      8        2310           1830
# 21594  1523300141  402101.0         1020      7        1020           1020
# 21595   291310100  400000.0         1600      8        1600           1410
# 21596  1523300157  325000.0         1020      7        1020           1020
#
#        bathrooms  view  bedrooms      lat  waterfront  floors
# 0           1.00   0.0         3  47.5112         NaN     1.0
# 1           2.25   0.0         3  47.7210         0.0     2.0
# 2           1.00   0.0         2  47.7379         0.0     1.0
# 3           3.00   0.0         4  47.5208         0.0     1.0
# 4           2.00   0.0         3  47.6168         0.0     1.0
# ...          ...   ...       ...      ...         ...     ...
# 21592       2.50   0.0         3  47.6993         0.0     3.0
# 21593       2.50   0.0         4  47.5107         0.0     2.0
# 21594       0.75   0.0         2  47.5944         0.0     2.0
# 21595       2.50   0.0         3  47.5345         NaN     2.0
# 21596       0.75   0.0         2  47.5941         0.0     2.0
#
# [21597 rows x 12 columns]

# %%
corr = new_df.corr()
corr
# Out:
#                      id     price  sqft_living     grade  sqft_above  \
# id             1.000000 -0.016772    -0.012241  0.008188   -0.010799
# price         -0.016772  1.000000     0.701917  0.667951    0.605368
# sqft_living   -0.012241  0.701917     1.000000  0.762779    0.876448
# grade          0.008188  0.667951     0.762779  1.000000    0.756073
# sqft_above    -0.010799  0.605368     0.876448  0.756073    1.000000
# sqft_living15 -0.002701  0.585241     0.756402  0.713867    0.731767
# bathrooms      0.005162  0.525906     0.755758  0.665838    0.686668
# view           0.011592  0.395734     0.282532  0.249727    0.166299
# bedrooms       0.001150  0.308787     0.578212  0.356563    0.479386
# lat           -0.001798  0.306692     0.052155  0.113575   -0.001199
# waterfront    -0.004176  0.276295     0.110230  0.087383    0.075463
# floors         0.018608  0.256804     0.353953  0.458794    0.523989
#
#                sqft_living15  bathrooms      view  bedrooms       lat  \
# id                 -0.002701   0.005162  0.011592  0.001150 -0.001798
# price               0.585241   0.525906  0.395734  0.308787  0.306692
# sqft_living         0.756402   0.755758  0.282532  0.578212  0.052155
# grade               0.713867   0.665838  0.249727  0.356563  0.113575
# sqft_above          0.731767   0.686668  0.166299  0.479386 -0.001199
# sqft_living15       1.000000   0.569884  0.279561  0.393406  0.048679
# bathrooms           0.569884   1.000000  0.186451  0.514508  0.024280
# view                0.279561   0.186451  1.000000  0.078523  0.006141
# bedrooms            0.393406   0.514508  0.078523  1.000000 -0.009951
# lat                 0.048679   0.024280  0.006141 -0.009951  1.000000
# waterfront          0.088860   0.067282  0.406654 -0.002386 -0.012772
# floors              0.280102   0.502582  0.028436  0.177944  0.049239
#
#                waterfront    floors
# id              -0.004176  0.018608
# price            0.276295  0.256804
# sqft_living      0.110230  0.353953
# grade            0.087383  0.458794
# sqft_above       0.075463  0.523989
# sqft_living15    0.088860  0.280102
# bathrooms        0.067282  0.502582
# view             0.406654  0.028436
# bedrooms        -0.002386  0.177944
# lat             -0.012772  0.049239
# waterfront       1.000000  0.021883
# floors           0.021883  1.000000

# %%
import seaborn as sns


g = sns.pairplot(new_df, vars=["bedrooms", "price"])


import matplotlib.pyplot as plt
plt.show()

# %%
# import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error as mse
# %matplotlib inline

# %%
new_df = new_df.dropna()
new_df = new_df.drop(labels=15856, axis=0)

# %%
plt.scatter(new_df.bedrooms, new_df.price, color='red')
plt.xlabel('Room Number')
plt.ylabel('Home Price (in millions)')
plt.title('Home Price per Room Number')
plt.xticks(np.arange(0, 12, 1))
plt.yticks(np.arange(0, 8000000, 500000))
plt.show()
#Create scatter plot to analyaze the price differences between number of bedrooms/observe which number of rooms is most popular.

# %%
corr = new_df.corr()
corr
# Out:
#                      id     price  sqft_living     grade  sqft_above  \
# id             1.000000 -0.018097    -0.012085  0.007820   -0.011776
# price         -0.018097  1.000000     0.704441  0.667733    0.609638
# sqft_living   -0.012085  0.704441     1.000000  0.763697    0.877670
# grade          0.007820  0.667733     0.763697  1.000000    0.757402
# sqft_above    -0.011776  0.609638     0.877670  0.757402    1.000000
# sqft_living15 -0.001372  0.582478     0.755522  0.713760    0.732856
# bathrooms      0.006923  0.526620     0.755906  0.666471    0.687617
# view           0.014619  0.395772     0.285970  0.248891    0.168685
# bedrooms       0.005034  0.317152     0.594821  0.370531    0.495244
# lat           -0.005554  0.306367     0.054237  0.115897    0.003437
# waterfront    -0.004876  0.270984     0.107415  0.085643    0.073498
# floors         0.018152  0.258815     0.356924  0.458217    0.525019
#
#                sqft_living15  bathrooms      view  bedrooms       lat  \
# id                 -0.001372   0.006923  0.014619  0.005034 -0.005554
# price               0.582478   0.526620  0.395772  0.317152  0.306367
# sqft_living         0.755522   0.755906  0.285970  0.594821  0.054237
# grade               0.713760   0.666471  0.248891  0.370531  0.115897
# sqft_above          0.732856   0.687617  0.168685  0.495244  0.003437
# sqft_living15       1.000000   0.569437  0.276711  0.405097  0.048540
# bathrooms           0.569437   1.000000  0.186974  0.531233  0.026220
# view                0.276711   0.186974  1.000000  0.086371  0.010432
# bedrooms            0.405097   0.531233  0.086371  1.000000 -0.012996
# lat                 0.048540   0.026220  0.010432 -0.012996  1.000000
# waterfront          0.087255   0.064606  0.406654 -0.004046 -0.012907
# floors              0.280196   0.506049  0.029133  0.188513  0.051600
#
#                waterfront    floors
# id              -0.004876  0.018152
# price            0.270984  0.258815
# sqft_living      0.107415  0.356924
# grade            0.085643  0.458217
# sqft_above       0.073498  0.525019
# sqft_living15    0.087255  0.280196
# bathrooms        0.064606  0.506049
# view             0.406654  0.029133
# bedrooms        -0.004046  0.188513
# lat             -0.012907  0.051600
# waterfront       1.000000  0.021395
# floors           0.021395  1.000000

# %%
#predictive means we must use sklearn
#create a linear regression without statsmodels
#fit and score linear regression and statsmodel
#attribute 
#reg.coeff_ (array of all coeffs)

# %% [markdown]
# #iterate zipcode lat and long coeffs
# #compare the coeffs to each other

# %% [markdown]
# Auburn School District - 98002-4452
# Bellevue School District - 98005-3183
# Enumclaw School District -  98022-7499
# Federal Way School District - 98003-5433
# Highline School District - 98166-0100
# Issaquah School District - 98027-2899
# Kent School District - 98031-6643
# Lake Washington School District - 98073-9739
# Mercer Island School District - 98040-4196
# Northshore School District - 98021-8972
# Renton School District - 98057
# Riverview School District - 98019
# Seattle Public Schools - 98124-1165
# Shoreline School District - 98155-2118
# Snoqualmie Valley School District - 98065-0400
# Tahoma School District - 98401-1357
# Tukwila School District - 98168-4134
# Vashon Island School District - 98070-0547

# %%
def sch_district(zipcode):
    zipcode = int()
    if zipcode == 98040:
        return 'Mercer Island'
    if zipcode == 98004 or 98005 or 98006 or 98007 or 98008 or 98039:
        return 'Bellevue'
    if zipcode == 98052:
        return 'Lake Washington'
    if zipcode == 98027 or 98029:
        return 'Issaquah'
    if zipcode == 98038 or 98042:
        return 'Tahoma'
    if zipcode == 98115:
        return 'Shoreline'
    if zipcode == 98070:
        return 'Vashon'
    if zipcode == 98065 or 98068 or 98024:
        return 'Snoqualmie'
    if zipcode == 98124 or 98117 or 98148:
        return 'Seattle'
    if zipcode == 98019:
        return 'Riverview'
    if zipcode == 98002 or 98092 or 98001:
        return 'Auburn'
    if zipcode == 98022:
        return 'Enumclaw'
    if zipcode == 98288:
        return 'Skykomish'
    if zipcode == 98028 or 98032 or 98010:
        return 'Kent'
    if zipcode == 98055 or 98056 or 98057 or 98059:
        return 'Renton'
    if zipcode == 98003 or 98023:
        return 'Federal Way'
    if zipcode == 98116:
        return 'Highline'
    if zipcode == 98118:
        return 'Tukwila'
    if zipcode == 98092:
        return 'Muckleshoot'
    else:
        return 'Zipcode is not in range of King County School Districts'

# %%
def sch_dist_grade(zipcode):
    zipcode_c = int(zipcode)
    if zipcode_c == 98040 or 98004 or 98005 or  98006 or  98007 or  98008or  98052 or  98027 or  98029 or  98039:
        return 'A+'
    if zipcode_c == 98038 or  98042 or  98115 or  98070:
        return 'A'
    if zipcode_c == 98065 or  98068 or 98101 or 98102 or 98103 or 98124 or 98125 or 98024 or 98148:
        return 'A-'
    if zipcode_c == 98019:
        return 'B+'
    if zipcode_c == 98002 and 98092 or 98022 or 98288 or 98028 or 98032 or 98001 or 98010:
        return 'B'
    if zipcode_c == 98052 or 98055 or 98056 or 98057 or 98059:
        return 'B-'
    if zipcode_c == 98003 or 98023 or 98116 or 98118:
        return 'C+'
    if zipcode_c == 98092:
        return 'D+'
    else:
        return 0

# %%
zipcode_grade = df['zipcode'].apply(sch_dist_grade)

# %%
school_district = df['zipcode'].apply(sch_district)

# %%
df = df.dropna()
df
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 1      6414100192   12/9/2014   538000.0         3       2.25         2570
# 3      2487200875   12/9/2014   604000.0         4       3.00         1960
# 4      1954400510   2/18/2015   510000.0         3       2.00         1680
# 5      7237550310   5/12/2014  1230000.0         4       4.50         5420
# 6      1321400060   6/27/2014   257500.0         3       2.25         1715
# ...           ...         ...        ...       ...        ...          ...
# 21591  2997800021   2/19/2015   475000.0         3       2.50         1310
# 21592   263000018   5/21/2014   360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015   400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014   402101.0         2       0.75         1020
# 21596  1523300157  10/15/2014   325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 1          7242     2.0         0.0   0.0  ...      7        2170
# 3          5000     1.0         0.0   0.0  ...      7        1050
# 4          8080     1.0         0.0   0.0  ...      8        1680
# 5        101930     1.0         0.0   0.0  ...     11        3890
# 6          6819     2.0         0.0   0.0  ...      7        1715
# ...         ...     ...         ...   ...  ...    ...         ...
# 21591      1294     2.0         0.0   0.0  ...      8        1180
# 21592      1131     3.0         0.0   0.0  ...      8        1530
# 21593      5813     2.0         0.0   0.0  ...      8        2310
# 21594      1350     2.0         0.0   0.0  ...      7        1020
# 21596      1076     2.0         0.0   0.0  ...      7        1020
#
#        sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# 1              400.0     1951        1991.0    98125  47.7210 -122.319
# 3              910.0     1965           0.0    98136  47.5208 -122.393
# 4                0.0     1987           0.0    98074  47.6168 -122.045
# 5             1530.0     2001           0.0    98053  47.6561 -122.005
# 6                  ?     1995           0.0    98003  47.3097 -122.327
# ...              ...      ...           ...      ...      ...      ...
# 21591          130.0     2008           0.0    98116  47.5773 -122.409
# 21592            0.0     2009           0.0    98103  47.6993 -122.346
# 21593            0.0     2014           0.0    98146  47.5107 -122.362
# 21594            0.0     2009           0.0    98144  47.5944 -122.299
# 21596            0.0     2008           0.0    98144  47.5941 -122.299
#
#        sqft_living15  sqft_lot15
# 1               1690        7639
# 3               1360        5000
# 4               1800        7503
# 5               4760      101930
# 6               2238        6819
# ...              ...         ...
# 21591           1330        1265
# 21592           1530        1509
# 21593           1830        7200
# 21594           1020        2007
# 21596           1020        1357
#
# [15762 rows x 21 columns]

# %%
df = df.drop(labels=15856, axis=0)
df
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 1      6414100192   12/9/2014   538000.0         3       2.25         2570
# 3      2487200875   12/9/2014   604000.0         4       3.00         1960
# 4      1954400510   2/18/2015   510000.0         3       2.00         1680
# 5      7237550310   5/12/2014  1230000.0         4       4.50         5420
# 6      1321400060   6/27/2014   257500.0         3       2.25         1715
# ...           ...         ...        ...       ...        ...          ...
# 21591  2997800021   2/19/2015   475000.0         3       2.50         1310
# 21592   263000018   5/21/2014   360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015   400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014   402101.0         2       0.75         1020
# 21596  1523300157  10/15/2014   325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 1          7242     2.0         0.0   0.0  ...      7        2170
# 3          5000     1.0         0.0   0.0  ...      7        1050
# 4          8080     1.0         0.0   0.0  ...      8        1680
# 5        101930     1.0         0.0   0.0  ...     11        3890
# 6          6819     2.0         0.0   0.0  ...      7        1715
# ...         ...     ...         ...   ...  ...    ...         ...
# 21591      1294     2.0         0.0   0.0  ...      8        1180
# 21592      1131     3.0         0.0   0.0  ...      8        1530
# 21593      5813     2.0         0.0   0.0  ...      8        2310
# 21594      1350     2.0         0.0   0.0  ...      7        1020
# 21596      1076     2.0         0.0   0.0  ...      7        1020
#
#        sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# 1              400.0     1951        1991.0    98125  47.7210 -122.319
# 3              910.0     1965           0.0    98136  47.5208 -122.393
# 4                0.0     1987           0.0    98074  47.6168 -122.045
# 5             1530.0     2001           0.0    98053  47.6561 -122.005
# 6                  ?     1995           0.0    98003  47.3097 -122.327
# ...              ...      ...           ...      ...      ...      ...
# 21591          130.0     2008           0.0    98116  47.5773 -122.409
# 21592            0.0     2009           0.0    98103  47.6993 -122.346
# 21593            0.0     2014           0.0    98146  47.5107 -122.362
# 21594            0.0     2009           0.0    98144  47.5944 -122.299
# 21596            0.0     2008           0.0    98144  47.5941 -122.299
#
#        sqft_living15  sqft_lot15
# 1               1690        7639
# 3               1360        5000
# 4               1800        7503
# 5               4760      101930
# 6               2238        6819
# ...              ...         ...
# 21591           1330        1265
# 21592           1530        1509
# 21593           1830        7200
# 21594           1020        2007
# 21596           1020        1357
#
# [15761 rows x 21 columns]

# %%
df["date"] = df.date.apply(lambda x: x[-4:])
type(df['date'])
# Out:
# pandas.core.series.Series

# %%
df = df.replace('?',np.nan)

df = df.dropna()

# %%
df = df.drop(labels=3220, axis=0)

# %%
import numpy as np
from sklearn.linear_model import LinearRegression        
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from numpy import asarray
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.metrics import mean_squared_error as mse
from scipy.stats import zscore
from scipy.stats import stats

# %%
reg = LinearRegression()
y = df['price']
X = df.drop(['id', 'price'], axis = 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42)

# %%
encoder = OneHotEncoder(sparse=False)
encoder.fit(X_train[['view', 'grade', 'zipcode']])
transformed_train = encoder.transform(X_train[['view', 'grade', 'zipcode']])
transformed_train = pd.DataFrame(transformed_train, columns = encoder.get_feature_names(), index=X_train.index)
X_train_encoded = pd.concat([X_train.drop(['view', 'grade', 'zipcode'], axis = 1), transformed_train], axis = 1)
test_condition = encoder.transform(X_test[['view', 'grade', 'zipcode']])
test_condition = pd.DataFrame(test_condition, columns=encoder.get_feature_names(), index=X_test.index)
test_condition = pd.concat([X_test.drop(['view', 'grade', 'zipcode'], axis = 1), test_condition], axis = 1)

# %%
reg.fit(X_train_encoded, y_train)
reg.score(X_train_encoded, y_train)
# Out:
# 0.840624332728187

# %%
reg.score(test_condition, y_test)
# Out:
# 0.8145009320259429

# %%
train_preds = reg.predict(X_train_encoded)
test_preds = reg.predict(test_condition)

# %%
np.sqrt(mse(y_train, train_preds))
# Out:
# 143663.9785123915

# %%
mse(y_test, test_preds, squared=False)
# Out:
# 176476.39588833158

# %%
df_2 = df.copy()
df_2
# Out:
#                id  date      price  bedrooms  bathrooms  sqft_living  \
# 1      6414100192  2014   538000.0         3       2.25         2570
# 3      2487200875  2014   604000.0         4       3.00         1960
# 4      1954400510  2015   510000.0         3       2.00         1680
# 5      7237550310  2014  1230000.0         4       4.50         5420
# 8      2414600126  2015   229500.0         3       1.00         1780
# ...           ...   ...        ...       ...        ...          ...
# 21591  2997800021  2015   475000.0         3       2.50         1310
# 21592   263000018  2014   360000.0         3       2.50         1530
# 21593  6600060120  2015   400000.0         4       2.50         2310
# 21594  1523300141  2014   402101.0         2       0.75         1020
# 21596  1523300157  2014   325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 1          7242     2.0         0.0   0.0  ...      7        2170
# 3          5000     1.0         0.0   0.0  ...      7        1050
# 4          8080     1.0         0.0   0.0  ...      8        1680
# 5        101930     1.0         0.0   0.0  ...     11        3890
# 8          7470     1.0         0.0   0.0  ...      7        1050
# ...         ...     ...         ...   ...  ...    ...         ...
# 21591      1294     2.0         0.0   0.0  ...      8        1180
# 21592      1131     3.0         0.0   0.0  ...      8        1530
# 21593      5813     2.0         0.0   0.0  ...      8        2310
# 21594      1350     2.0         0.0   0.0  ...      7        1020
# 21596      1076     2.0         0.0   0.0  ...      7        1020
#
#        sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# 1              400.0     1951        1991.0    98125  47.7210 -122.319
# 3              910.0     1965           0.0    98136  47.5208 -122.393
# 4                0.0     1987           0.0    98074  47.6168 -122.045
# 5             1530.0     2001           0.0    98053  47.6561 -122.005
# 8              730.0     1960           0.0    98146  47.5123 -122.337
# ...              ...      ...           ...      ...      ...      ...
# 21591          130.0     2008           0.0    98116  47.5773 -122.409
# 21592            0.0     2009           0.0    98103  47.6993 -122.346
# 21593            0.0     2014           0.0    98146  47.5107 -122.362
# 21594            0.0     2009           0.0    98144  47.5944 -122.299
# 21596            0.0     2008           0.0    98144  47.5941 -122.299
#
#        sqft_living15  sqft_lot15
# 1               1690        7639
# 3               1360        5000
# 4               1800        7503
# 5               4760      101930
# 8               1780        8113
# ...              ...         ...
# 21591           1330        1265
# 21592           1530        1509
# 21593           1830        7200
# 21594           1020        2007
# 21596           1020        1357
#
# [15427 rows x 21 columns]

# %%
q_low = df_2["price"].quantile(0.01)
q_hi  = df_2["price"].quantile(0.99)

df_filtered = df_2[(df_2["price"] < q_hi) & (df_2["price"] > q_low)]

# %%
df_filtered.grade.sort_values(ascending=False)
# Out:
# 5446     13
# 6495     12
# 18767    12
# 16511    12
# 15152    12
#          ..
# 9632      4
# 8614      4
# 18152     4
# 5199      4
# 11488     4
# Name: grade, Length: 15116, dtype: int64

# %%
df_filtered = df_filtered.drop(labels=5446, axis=0)

# %%
reg_2 = LinearRegression()
y = df_filtered['price']
X = df_filtered.drop(['id', 'price'], axis = 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42)

# %%
X_test['grade'].value_counts()
# Out:
# 7     1575
# 8     1074
# 9      516
# 6      306
# 10     188
# 11      69
# 5       39
# 12      10
# 4        2
# Name: grade, dtype: int64

# %%
encoder = OneHotEncoder(sparse=False)
encoder.fit(X_train[['view', 'grade', 'zipcode']])
transformed_train = encoder.transform(X_train[['view', 'grade', 'zipcode']])
transformed_train = pd.DataFrame(transformed_train, columns = encoder.get_feature_names(), index=X_train.index)
X_train_encoded = pd.concat([X_train.drop(['view', 'grade', 'zipcode'], axis = 1), transformed_train], axis = 1)
test_condition = encoder.transform(X_test[['view', 'grade', 'zipcode']])
test_condition = pd.DataFrame(test_condition, columns=encoder.get_feature_names(), index=X_test.index)
test_condition = pd.concat([X_test.drop(['view', 'grade', 'zipcode'], axis = 1), test_condition], axis = 1)

# %%
reg.fit(X_train_encoded, y_train)
reg.score(X_train_encoded, y_train)
# Out:
# 0.8492893553644953

# %%
reg.score(test_condition, y_test)
# Out:
# 0.8556678891117264

# %%
train_preds = reg.predict(X_train_encoded)
test_preds = reg.predict(test_condition)

# %%
np.sqrt(mse(y_train, train_preds))
# Out:
# 109665.08353490481

# %%
mse(y_test, test_preds, squared=False)
# Out:
# 109613.52076837461

# %%
df_3 = df_filtered.copy()

# %%
df_3['yr_renovated'].value_counts()
# Out:
# 0.0       14508
# 2014.0       61
# 2013.0       29
# 2005.0       27
# 2000.0       25
#           ...
# 1974.0        1
# 1944.0        1
# 1967.0        1
# 1951.0        1
# 1945.0        1
# Name: yr_renovated, Length: 68, dtype: int64

# %%
reg_3 = LinearRegression()
y = df_3['price']
X = df_3.drop(['id', 'price',], axis = 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42)

# %%
encoder = OneHotEncoder(sparse=False)
encoder.fit(X_train[['view', 'grade', 'zipcode']])
transformed_train = encoder.transform(X_train[['view', 'grade', 'zipcode']])
transformed_train = pd.DataFrame(transformed_train, columns = encoder.get_feature_names(), index=X_train.index)
X_train_encoded = pd.concat([X_train.drop(['view', 'grade', 'zipcode'], axis = 1), transformed_train], axis = 1)
test_condition = encoder.transform(X_test[['view', 'grade', 'zipcode']])
test_condition = pd.DataFrame(test_condition, columns=encoder.get_feature_names(), index=X_test.index)
test_condition = pd.concat([X_test.drop(['view', 'grade', 'zipcode'], axis = 1), test_condition], axis = 1)

# %%
reg.fit(X_train_encoded, y_train)
reg.score(X_train_encoded, y_train)
# Out:
# 0.8492893553644953

# %%
reg.score(test_condition, y_test)
# Out:
# 0.8556678891117264

# %%
train_preds = reg.predict(X_train_encoded)
test_preds = reg.predict(test_condition)

# %%
np.sqrt(mse(y_train, train_preds))
# Out:
# 109665.08353490481

# %%
mse(y_test, test_preds, squared=False)
# Out:
# 109613.52076837461
